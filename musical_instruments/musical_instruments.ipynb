# %%
import json

import gensim
from gensim.models import Word2Vec

import pandas as pd

import nltk
from nltk.stem import WordNetLemmatizer

import re

from sklearn.decomposition import PCA, KernelPCA

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
# Out:
# c:\users\yasht\fakenews\venv\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# nltk.download('punkt')
# nltk.download('stopwords')

# %% [markdown]
# # Loading reviews

# %%
# Read reviews
# Data obtained from https://jmcauley.ucsd.edu/data/amazon/
with open('Musical_Instruments_5.json') as data_file:
    def load_review(line):
        review = json.loads(line)
        return [float(review['overall']), review['reviewText']]
    reviews = list(map(load_review, data_file))

# %%
reviews[0]
# Out:
# [5.0,
#  "Not much to write about here, but it does exactly what it's supposed to. filters out the pop sounds. now my recordings are much more crisp. it is one of the lowest prices pop filters on amazon so might as well buy it, they honestly work the same despite their pricing,"]

# %%
review_df = pd.DataFrame(reviews, columns=['Rating', 'Text'])

# %%
review_df
# Out:
#        Rating                                               Text
# 0         5.0  Not much to write about here, but it does exac...
# 1         5.0  The product does exactly as it should and is q...
# 2         5.0  The primary job of this device is to block the...
# 3         5.0  Nice windscreen protects my MXL mic and preven...
# 4         5.0  This pop filter is great. It looks and perform...
# ...       ...                                                ...
# 10256     5.0            Great, just as expected.  Thank to all.
# 10257     5.0  I've been thinking about trying the Nanoweb st...
# 10258     4.0  I have tried coated strings in the past ( incl...
# 10259     4.0  Well, MADE by Elixir and DEVELOPED with Taylor...
# 10260     4.0  These strings are really quite good, but I wou...
#
# [10261 rows x 2 columns]

# %%
en_stop = set(nltk.corpus.stopwords.words('english'))
stemmer = WordNetLemmatizer()

def tokenize(text):
    text = text.lower()
    # Remove non-word characters
    text = re.sub(r'[^a-z]', ' ', text)
    # Remove single characters
    text = re.sub(r'\b[a-z]\b', ' ', text)
    text = re.sub(r'\s+', ' ', text)

    # Lemmatization
    tokens = text.split()
    tokens = [stemmer.lemmatize(word) for word in tokens]
    tokens = [word for word in tokens if len(word) >= 4 and word not in en_stop]
    
    return tokens

# %%
review_df['Tokens'] = review_df['Text'].apply(tokenize)

# %%
review_df[['Rating', 'Tokens']]
# Out:
#        Rating                                             Tokens
# 0         5.0  [much, write, exactly, supposed, filter, sound...
# 1         5.0  [product, exactly, quite, affordable, realized...
# 2         5.0  [primary, device, block, breath, would, otherw...
# 3         5.0  [nice, windscreen, protects, prevents, thing, ...
# 4         5.0  [filter, great, look, performs, like, studio, ...
# ...       ...                                                ...
# 10256     5.0                           [great, expected, thank]
# 10257     5.0  [thinking, trying, nanoweb, string, high, pric...
# 10258     4.0  [tried, coated, string, past, including, elixi...
# 10259     4.0  [well, made, elixir, developed, taylor, guitar...
# 10260     4.0  [string, really, quite, good, call, perfect, u...
#
# [10261 rows x 2 columns]

# %% [markdown]
# # Creating w2v model

# %%
model_file = 'musical_instruments_review_word2vec_len4.model' # change every time!

# %%
model = Word2Vec(sentences=review_df['Tokens'])
model.save(model_file)

# %%
model = Word2Vec.load(model_file)

# %% [markdown]
# # PCA stuff

# %%
vocab = np.array(list(model.wv.key_to_index.keys()))
num_words, = vocab.shape
print('Vocab has ', num_words, 'words')
vocab[:10]
# Out:
# Vocab has  5014 words
# array(['guitar', 'string', 'sound', 'great', 'like', 'good', 'pedal',
#        'well', 'work', 'would'], dtype='<U15')

# %%
vectors = model.wv[model.wv.index_to_key]

# %%
pd.DataFrame(vectors)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.633566  0.998092  0.582789 -0.258343 -0.388207 -0.587015 -0.051465
# 1    -1.108007  0.618956  1.085505 -0.741413 -0.124979 -0.822176 -0.438003
# 2    -0.281586  0.314040  0.337559 -1.082123  1.004842 -0.606041 -0.995257
# 3    -0.351859  0.660893  0.276153  0.127790 -0.196176 -0.266232  0.485263
# 4    -0.305512  0.572164 -0.020004 -0.109185  0.009766 -0.342764 -0.085980
# ...        ...       ...       ...       ...       ...       ...       ...
# 5009 -0.042885  0.062788  0.028355  0.013230  0.002425 -0.030738 -0.006579
# 5010 -0.048850  0.076957  0.043755  0.001938  0.011239 -0.027981  0.008062
# 5011 -0.040560  0.045501  0.035476 -0.010130  0.026669 -0.021318 -0.020123
# 5012 -0.040634  0.068257  0.026774  0.018714  0.007811 -0.017896  0.000014
# 5013 -0.034162  0.059132  0.027544  0.025453  0.003786 -0.020278 -0.006443
#
#             7         8         9   ...        90        91        92  \
# 0     0.352805 -0.443032 -0.566259  ...  1.046474 -0.621652 -0.608239
# 1     1.091545 -0.743060 -0.390128  ...  1.594185  0.276080 -0.191636
# 2     0.839479  0.236430  0.465603  ...  0.874011  0.967354  0.799581
# 3     0.917570 -0.102091 -1.171632  ...  0.537855  0.445876 -0.121456
# 4     1.106441  0.039060 -0.297917  ...  0.643142  0.246425 -0.266685
# ...        ...       ...       ...  ...       ...       ...       ...
# 5009  0.082950 -0.026382 -0.000384  ...  0.079355 -0.009535 -0.000106
# 5010  0.079804 -0.019680 -0.006525  ...  0.089637 -0.015928  0.013299
# 5011  0.066820 -0.012227  0.009176  ...  0.048439  0.014377  0.016493
# 5012  0.097455 -0.030387 -0.022625  ...  0.095833  0.007562  0.022524
# 5013  0.067441 -0.032178 -0.007317  ...  0.102199 -0.021205  0.026081
#
#             93        94        95        96        97        98        99
# 0    -0.521442  0.444447  0.144791 -0.963137  0.390991  0.456061  0.344259
# 1    -1.209997 -0.165464  0.624543  0.025453  0.367595  0.732428  0.244073
# 2    -0.368658  0.759488  1.250912  0.953397  0.117541  0.310760 -0.707142
# 3     0.384465  1.084071  1.001408  0.213377 -0.470557  0.279414 -0.157617
# 4    -0.288111  0.463989 -0.330046  0.746318 -0.351893 -0.062771 -0.053087
# ...        ...       ...       ...       ...       ...       ...       ...
# 5009 -0.016546  0.035763  0.041962 -0.028560 -0.020926  0.039903 -0.008657
# 5010 -0.011555  0.051152  0.073488 -0.018838 -0.013366  0.009799 -0.020533
# 5011  0.008276  0.036542  0.053048  0.025043 -0.013016 -0.000035 -0.011655
# 5012  0.008359  0.067789  0.049347 -0.010243 -0.034313  0.023453 -0.030282
# 5013 -0.020301  0.031425  0.047708 -0.045717 -0.015216  0.037616 -0.015369
#
# [5014 rows x 100 columns]

# %%
def try_pca(pca):
    pca = pca.fit(vectors)
    top = pca.explained_variance_ratio_
    print(top, sum(top))
    return pca

# %%
pca1 = try_pca(PCA(n_components=2))
# Out:
# [0.3378459  0.17996788] 0.5178137719631195

# %%
pca2 = try_pca(PCA(n_components=3))
# Out:
# [0.33784595 0.17996776 0.1181828 ] 0.635996513068676

# %%
pca3 = try_pca(PCA(n_components=3, svd_solver='arpack'))
# Out:
# [0.337846   0.17996788 0.11818296] 0.6359968557953835

# %%
pca4 = try_pca(PCA(n_components=3, svd_solver='full'))
# Out:
# [0.33784586 0.1799677  0.1181829 ] 0.6359964609146118

# %%
pca4 = try_pca(PCA(n_components=3, svd_solver='randomized'))
# Out:
# [0.33784592 0.17996788 0.11818296] 0.6359967663884163

# %%
pca5 = try_pca(PCA(n_components=4, svd_solver='arpack'))
# Out:
# [0.337846   0.17996792 0.11818305 0.1024633 ] 0.7384602874517441

# %%
pca6 = try_pca(PCA(n_components=4, svd_solver='full'))
# Out:
# [0.33784586 0.1799677  0.1181829  0.10246312] 0.7384595796465874

# %%
pca7 = try_pca(PCA())
# Out:
# [3.37845862e-01 1.79967701e-01 1.18182898e-01 1.02463119e-01
#  7.77704716e-02 4.69521321e-02 3.18253189e-02 2.44227853e-02
#  1.50305359e-02 1.24601731e-02 9.62212030e-03 8.88107810e-03
#  6.85979147e-03 5.03673404e-03 3.79405194e-03 2.71534570e-03
#  2.08122307e-03 1.93970825e-03 1.57582655e-03 1.32534420e-03
#  9.90501489e-04 8.53063306e-04 6.67409739e-04 5.93924953e-04
#  5.10427053e-04 4.54654917e-04 3.90656409e-04 3.28868511e-04
#  3.02311993e-04 2.79505563e-04 2.38051201e-04 2.18296511e-04
#  2.02803465e-04 1.87551253e-04 1.81580268e-04 1.50671665e-04
#  1.48074454e-04 1.28856875e-04 1.17970216e-04 1.10875742e-04
#  9.48004090e-05 9.00755767e-05 8.67925191e-05 8.23261071e-05
#  8.12169237e-05 7.88096222e-05 7.00638848e-05 6.71502639e-05
#  6.03017288e-05 5.94043631e-05 5.31677106e-05 5.02933472e-05
#  4.64225086e-05 4.39537071e-05 4.31395638e-05 4.19404969e-05
#  4.14803617e-05 3.96261530e-05 3.79027697e-05 3.71702554e-05
#  3.64996522e-05 3.58659236e-05 3.34647120e-05 3.32876734e-05
#  3.23710228e-05 3.13899000e-05 3.09000206e-05 3.05161502e-05
#  2.90664575e-05 2.88829906e-05 2.80102759e-05 2.72579618e-05
#  2.68070326e-05 2.61389505e-05 2.56919448e-05 2.55479808e-05
#  2.46972140e-05 2.45259544e-05 2.40726240e-05 2.36402848e-05
#  2.34293384e-05 2.29435300e-05 2.28157533e-05 2.24863252e-05
#  2.24219057e-05 2.21842765e-05 2.17450925e-05 2.08075417e-05
#  2.04939970e-05 2.00941431e-05 1.99777151e-05 1.98605994e-05
#  1.93745072e-05 1.92484713e-05 1.87555888e-05 1.84968721e-05
#  1.82419226e-05 1.80572424e-05 1.79120816e-05 1.76113954e-05] 0.9999999070350896

# %%
pca8 = KernelPCA()
# try_pca(pca8)
# pca8

# %%
pca = pca2

# %%
pca_vectors = pca.transform(vectors)

# %%
pca_vectors.shape, pca_vectors
# Out:
# ((5014, 3),
#  array([[ 1.5883707 , -3.3075602 ,  0.99115264],
#         [ 2.385836  , -3.3833518 ,  5.16807   ],
#         [ 1.8391887 ,  2.7380075 ,  3.7999656 ],
#         ...,
#         [-0.9948362 ,  0.11064431,  0.06472747],
#         [-0.8542955 ,  0.03494074, -0.00800675],
#         [-0.8884225 , -0.05202955, -0.01208933]], dtype=float32))

# %% [markdown]
# # Visualization

# %%
xdata, ydata, zdata = pca_vectors.transpose()

# %%
def show_words(words_to_pick, size_3d=(25, 25), size_2d=(10, 10), words=True, xlim=(-1.5, 3.0), ylim=(-6.5, 6.5)):
    # The indices of the words to pick in vocab
    indices = [np.where(word == vocab)[0][0] for word in words_to_pick]
    # Keep only the vectors for the selected words
    sel_x, sel_y, sel_z = [arr[indices] for arr in [xdata, ydata, zdata]]
    if words:
        print(words_to_pick, sel_x, sel_y, sel_z, sep='\n')
    
    cm = plt.cm.get_cmap('gist_rainbow')
    font_size = 'x-large'
    
    fig = plt.figure(figsize=size_3d)
    ax = plt.axes(projection='3d')
    # Plot the word, with the color depending on the distance from the origin
    plot = ax.scatter(sel_x, sel_y, sel_z, c=(sel_x ** 2 + sel_y ** 2 + sel_z ** 2) ** 0.5, cmap=cm)
    print(plot)
    # Add the word itself to that point
    if words:
        for word, x, y, z in zip(words_to_pick, sel_x, sel_y, sel_z):
            ax.text(x, y, z, word, fontsize=font_size)
            
    plt.colorbar(plot)

    ax.set_xlabel('PCA Feature 1')
    ax.set_ylabel('PCA Feature 2')
    ax.set_zlabel('PCA Feature 3')
    
    ax.set_xlim(xlim[0], xlim[1])
    ax.set_ylim(ylim[0], ylim[1])
#     ax.set_zlim(zlim[0], zlim[1])

    plt.show()
    
    fig = plt.figure(figsize=size_2d)
    ax = plt.axes()
    # Plot each word, with the third feature being a color
    plot = plt.scatter(sel_x, sel_y, c=sel_z, cmap=cm)
    # Add the word itself to that point
    if words:
        for word, x, y in zip(words_to_pick, sel_x, sel_y):
            ax.text(x, y, word, fontsize=font_size)
        
    plt.colorbar(plot)
    
    ax.set_xlabel('PCA Feature 1')
    ax.set_ylabel('PCA Feature 2')
    
    ax.set_xlim(xlim[0], xlim[1])
    ax.set_ylim(ylim[0], ylim[1])

    plt.show()

# %%
show_words(vocab, words=False)
# Out:
# <mpl_toolkits.mplot3d.art3d.Path3DCollection object at 0x0000016E8C286190>

# %%
# # Randomly choose 10 words
# indices = np.random.choice(range(num_words), 10)

# %%
show_words(['guitar', 'piano', 'string', 'violin', 'viola', 'cello', 'drum', 'flute', 'trumpet'], size_2d=(15, 15))
# Out:
# ['guitar', 'piano', 'string', 'violin', 'viola', 'cello', 'drum', 'flute', 'trumpet']
# [ 1.5883707   1.1342871   2.385836    1.6435502  -0.78748924 -0.83252895
#   1.124234   -0.5426686  -0.63331866]
# [-3.3075602  -0.05749363 -3.3833518  -1.7744114  -0.10672264 -0.00866414
#   1.0031432  -0.03655626 -0.04131112]
# [ 0.99115264  0.27767155  5.16807     0.7378049   0.03696803  0.01866342
#  -0.01574892 -0.05355225  0.05342376]
# <mpl_toolkits.mplot3d.art3d.Path3DCollection object at 0x0000016E8B9C7A00>

# %%
pos_words = ['good', 'great', 'nice', 'well', 'excellent', 'love',
             'perfect', 'comfortable', 'durable', 'smooth', 'remarkable']
neg_words = ['terrible', 'horrible', 'flimsy', 'inferior', 'uncomfortable', 'difficult',
             'waste', 'suck', 'clunky', 'unusable', 'dead', 'unnecessary']
print(len(pos_words) - len(neg_words))
show_words(pos_words + neg_words, size_2d=(25, 25))
# Out:
# -1
# ['good', 'great', 'nice', 'well', 'excellent', 'love', 'perfect', 'comfortable', 'durable', 'smooth', 'remarkable', 'terrible', 'horrible', 'flimsy', 'inferior', 'uncomfortable', 'difficult', 'waste', 'suck', 'clunky', 'unusable', 'dead', 'unnecessary']
# [ 1.7237074   1.7412237   1.7226824   1.8031658   1.4134881   1.4276724
#   1.167736    1.682631    1.646569    1.634248   -0.7999124   0.6764908
#   0.59395087  1.0015757  -0.5197477   0.26275578  1.4064385   0.31826437
#   0.6586723  -0.82618165 -0.14115588  1.2521563  -0.18814023]
# [-0.04864391  0.13066171 -0.5165863  -1.2446202   0.70331067 -1.0982583
#  -0.6205508  -2.4699714  -0.98520005  0.8602347   0.01093448  0.03407484
#   0.2102296  -0.29436368  0.0246012  -0.35311064 -0.54890066 -0.10826403
#   0.62294275 -0.10301393  0.03417349  0.09661603  0.09916552]
# [ 0.6872319   0.82987165  1.657507   -0.74722934 -0.02483962  1.83333
#   0.3323581   0.5326429  -0.03552655  2.0343494   0.12927923  0.15307148
#  -0.06635474 -0.18370001 -0.04533315  0.06646428  0.11404864 -0.15549676
#   0.41930264  0.04275717  0.11573248  0.26811263 -0.22060257]
# <mpl_toolkits.mplot3d.art3d.Path3DCollection object at 0x0000016E8BB7FB20>

# %%
# Most common words
str(model.wv.index_to_key[:200])
# Out:
# "['guitar', 'one', 'string', 'sound', 'great', 'like', 'good', 'use', 'pedal', 'well', 'work', 'get', 'amp', 'would', 'price', 'pick', 'really', 'little', 'much', 'time', 'quality', 'tone', 'also', 'used', 'make', 'cable', 'nice', 'better', 'tuner', 'stand', 'doe', 'strap', 'need', 'thing', 'easy', 'using', 'play', 'bought', 'product', 'mic', 'even', 'year', 'buy', 'playing', 'look', 'want', 'way', 'set', 'acoustic', 'made', 'still', 'got', 'case', 'say', 'love', 'right', 'feel', 'instrument', 'bit', 'back', 'two', 'lot', 'bass', 'fit', 'first', 'best', 'problem', 'could', 'come', 'put', 'fender', 'enough', 'small', 'around', 'recommend', 'without', 'long', 'end', 'think', 'new', 'give', 'hold', 'effect', 'tune', 'cheap', 'last', 'keep', 'light', 'another', 'capo', 'know', 'take', 'high', 'different', 'pretty', 'power', 'find', 'review', 'many', 'perfect', 'fine', 'electric', 'looking', 'far', 'sure', 'see', 'try', 'microphone', 'something', 'never', 'though', 'recording', 'clean', 'low', 'volume', 'always', 'since', 'tube', 'metal', 'may', 'tried', 'hard', 'going', 'battery', 'neck', 'job', 'found', 'solid', 'tuning', 'music', 'seems', 'noise', 'money', 'board', 'star', 'box', 'unit', 'switch', 'size', 'needed', 'plastic', 'worth', 'however', 'every', 'heavy', 'easily', 'issue', 'distortion', 'knob', 'quite', 'big', 'probably', 'day', 'change', 'top', 'control', 'bag', 'built', 'gig', 'old', 'cost', 'amazon', 'might', 'actually', 'line', 'plug', 'simple', 'note', 'expensive', 'side', 'brand', 'hand', 'getting', 'highly', 'finger', 'setting', 'screw', 'ever', 'place', 'player', 'happy', 'came', 'behringer', 'speaker', 'studio', 'head', 'purchased', 'bad', 'almost', 'gain', 'clip', 'practice', 'sturdy', 'excellent', 'extra', 'difference', 'color', 'bos', 'home', 'several']"

# %%
show_words(['guitar', 'piano', 'string', 'pedal', 'tuner', 'pick', 'acoustic', 'cable', 'tuner',
            'instrument', 'capo', 'bass', 'speaker', 'board', 'metal', 'microphone', 'knob', 'tube',
            'volume', 'unit', 'switch', 'plastic', 'electric', 'music', 'line', 'plug', 'power',
            'finger', 'screw', 'studio', 'behringer', 'battery', 'control', 'note', 'player', 'practice'], size_2d=(22, 22))
# Out:
# ['guitar', 'piano', 'string', 'pedal', 'tuner', 'pick', 'acoustic', 'cable', 'tuner', 'instrument', 'capo', 'bass', 'speaker', 'board', 'metal', 'microphone', 'knob', 'tube', 'volume', 'unit', 'switch', 'plastic', 'electric', 'music', 'line', 'plug', 'power', 'finger', 'screw', 'studio', 'behringer', 'battery', 'control', 'note', 'player', 'practice']
# [1.5883707 1.1342871 2.385836  1.9963449 1.5723071 1.9844247 2.1467183
#  1.7985979 1.5723071 1.2918733 1.9275087 1.5184665 1.6639214 1.4745868
#  1.7477984 1.6632086 2.242875  1.9677439 2.4096732 1.343518  1.5412639
#  1.5755923 2.2828646 1.2691655 1.2804086 1.4729115 2.5202913 1.7867798
#  1.5569797 1.6185212 1.6639999 1.768958  2.310331  1.3220062 1.452919
#  1.2077217]
# [-3.3075602  -0.05749363 -3.3833518   4.5043583  -3.634544   -3.8278105
#  -2.859601    1.4568006  -3.634544   -2.0546036  -4.859758    0.24170375
#   4.0239124   3.2000582   1.8121835   1.9365606   3.950313    4.56315
#   5.4085383   2.4014237   3.0730765  -0.78722566 -3.2682543  -0.94375527
#   2.732327    2.342523    5.077985   -2.1246998  -1.6279795   2.045705
#   3.028923    0.81148875  4.889105    0.26808152 -1.209817    0.5674755 ]
# [ 0.99115264  0.27767155  5.16807     0.5643075  -0.05828622  2.4676688
#   2.907883   -4.5353484  -0.05828622 -0.21487056  0.23342268  2.8893013
#  -0.9159589  -1.7344948   1.7471279  -4.372343    2.1537411   2.1891303
#   3.1097765  -1.9224594   0.03312352 -1.2421062   2.4314196  -1.9201366
#  -0.8475904  -2.7739174  -4.4982967   3.408309   -2.9780002  -2.6582308
#  -1.5170325  -3.496555    1.3851656   2.2124488   1.7624813  -0.08229448]
# <mpl_toolkits.mplot3d.art3d.Path3DCollection object at 0x0000016E8C03E1F0>

# %%
show_words(model.wv.index_to_key[:200])
# Out:
# ['guitar', 'string', 'sound', 'great', 'like', 'good', 'pedal', 'well', 'work', 'would', 'price', 'pick', 'really', 'little', 'much', 'time', 'quality', 'tone', 'also', 'used', 'make', 'cable', 'nice', 'better', 'tuner', 'stand', 'strap', 'need', 'thing', 'easy', 'using', 'play', 'bought', 'product', 'even', 'year', 'playing', 'look', 'want', 'acoustic', 'made', 'still', 'case', 'love', 'right', 'feel', 'instrument', 'back', 'bass', 'first', 'best', 'problem', 'could', 'come', 'fender', 'enough', 'small', 'around', 'recommend', 'without', 'long', 'think', 'give', 'hold', 'effect', 'tune', 'cheap', 'last', 'keep', 'light', 'another', 'know', 'capo', 'take', 'high', 'different', 'pretty', 'power', 'find', 'review', 'many', 'perfect', 'fine', 'electric', 'looking', 'sure', 'microphone', 'something', 'never', 'though', 'recording', 'clean', 'volume', 'always', 'since', 'tube', 'metal', 'tried', 'hard', 'going', 'battery', 'neck', 'found', 'solid', 'tuning', 'seems', 'music', 'noise', 'money', 'board', 'star', 'unit', 'switch', 'size', 'needed', 'plastic', 'worth', 'every', 'however', 'easily', 'heavy', 'issue', 'distortion', 'knob', 'quite', 'probably', 'change', 'control', 'built', 'cost', 'amazon', 'might', 'line', 'actually', 'plug', 'simple', 'note', 'expensive', 'side', 'brand', 'hand', 'getting', 'highly', 'finger', 'setting', 'screw', 'ever', 'place', 'player', 'happy', 'came', 'behringer', 'speaker', 'head', 'studio', 'purchased', 'almost', 'gain', 'clip', 'practice', 'sturdy', 'excellent', 'extra', 'difference', 'color', 'home', 'several', 'people', 'level', 'part', 'three', 'type', 'purchase', 'model', 'definitely', 'seem', 'wanted', 'thought', 'standard', 'turn', 'button', 'anything', 'stay', 'perfectly', 'help', 'couple', 'blue', 'delay', 'hole', 'said', 'bright', 'read', 'headphone', 'nothing', 'range', 'rock', 'overdrive', 'deal', 'lock', 'month']
# [1.5883707 2.385836  1.8391887 1.7412237 1.4853404 1.7237074 1.9963449
#  1.8031658 1.4562607 1.3434317 1.9806108 1.9844247 1.3908857 1.1874642
#  1.4022368 1.6609035 1.8947227 2.501586  1.1134471 1.254     1.3076047
#  1.7985979 1.7226824 1.5517882 1.5723071 1.8072805 2.2931986 1.1541061
#  1.1579801 1.693083  1.0708221 1.521883  1.4171529 1.7471691 1.1800747
#  2.0083632 1.5326638 1.6369609 1.3025225 2.1467183 1.7394967 1.2326313
#  1.4978551 1.4276724 1.1012486 1.9213085 1.2918733 1.1755201 1.5184665
#  1.2417048 1.5790085 1.0462012 1.0860584 1.088975  1.4028614 1.5216262
#  1.2161776 1.1515703 2.3425512 1.0968499 2.185557  1.4036763 1.4261208
#  1.8470194 2.032263  2.1313653 1.5447758 2.7354736 1.4005141 1.6197274
#  1.1081918 1.2982243 1.9275087 1.205864  1.6978807 1.2696408 1.5716728
#  2.5202913 1.1765478 1.2950402 1.4954363 1.167736  1.3712604 2.2828646
#  1.46649   1.1840062 1.6632086 1.3063573 1.3440839 1.2636986 1.6416718
#  2.0840564 2.4096732 1.3551702 1.2105252 1.9677439 1.7477984 1.4412997
#  1.4071306 1.1208699 1.768958  1.7065165 1.1233425 1.6884408 1.5812695
#  1.5111556 1.2691655 1.5175432 1.821803  1.4745868 1.5821913 1.343518
#  -0.3149586   0.9284021   0.22302195 -0.19998561 -0.21522613  1.2447878
#  -1.5343304   0.13674201  1.2167395  -1.1381001   0.6616389  -0.4050863
#   2.22797     1.3809386  -1.058889    0.44409648  3.7711668  -0.1766941
#  -1.3577169  -0.13921733  1.4105566   3.1713958   2.6531894  -0.17514394
#  -1.5565574   0.13577025]
# <mpl_toolkits.mplot3d.art3d.Path3DCollection object at 0x0000016E8C236CA0>

# %%
# from functools import reduce

# def sum_sentence(sentence):
#     try:
#         def add_lists(xs, ys):
#             return map(lambda xy: xy[0] + xy[1], zip(xs, ys))
#         return list(reduce(add_lists, sentence, [0.0] * 100))
#     except:
#         print(sentence)
#         raise sentence
# sent_sums = review_df['Tokens'].apply(sum_sentence) #lambda sentence: reduce(lambda a, b: a + b, sentence, [0] * 100))
# Out:
# ['much', 'write', 'exactly', 'supposed', 'filter', 'sound', 'recording', 'much', 'crisp', 'lowest', 'price', 'filter', 'amazon', 'might', 'well', 'honestly', 'work', 'despite', 'pricing']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15960/3337114461.py in sum_sentence(sentence)
#       6             return map(lambda xy: xy[0] + xy[1], zip(xs, ys))
# ----> 7         return list(reduce(add_lists, sentence, [0.0] * 100))
#       8     except:
#
# ~\AppData\Local\Temp/ipykernel_15960/3337114461.py in <lambda>(xy)
#       5         def add_lists(xs, ys):
# ----> 6             return map(lambda xy: xy[0] + xy[1], zip(xs, ys))
#       7         return list(reduce(add_lists, sentence, [0.0] * 100))
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15960/3337114461.py in <module>
#       9         print(sentence)
#      10         raise sentence
# ---> 11 sent_sums = review_df['Tokens'].apply(sum_sentence) #lambda sentence: reduce(lambda a, b: a + b, sentence, [0] * 100))
#
# c:\users\yasht\fakenews\venv\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# c:\users\yasht\fakenews\venv\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# c:\users\yasht\fakenews\venv\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# c:\users\yasht\fakenews\venv\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_15960/3337114461.py in sum_sentence(sentence)
#       8     except:
#       9         print(sentence)
# ---> 10         raise sentence
#      11 sent_sums = review_df['Tokens'].apply(sum_sentence) #lambda sentence: reduce(lambda a, b: a + b, sentence, [0] * 100))
#
# TypeError: exceptions must derive from BaseException

# %%
sent_sums
# Out:
# 0        <map object at 0x0000016E8AB211F0>
# 1        <map object at 0x0000016E8AACBF10>
# 2        <map object at 0x0000016E8AB14370>
# 3        <map object at 0x0000016E8AAE0700>
# 4        <map object at 0x0000016E8AAE0040>
#                         ...
# 10256    <map object at 0x0000016E9BE71880>
# 10257    <map object at 0x0000016E9BE8B670>
# 10258    <map object at 0x0000016E9BE8FFA0>
# 10259    <map object at 0x0000016E9BE9F5B0>
# 10260    <map object at 0x0000016E9BEA6040>
# Name: Tokens, Length: 10261, dtype: object
